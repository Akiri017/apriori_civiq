# %% [markdown]
# # Colab Extension Test Notebook
# A simple notebook to verify the Colab extension is working correctly.

# %% [markdown]
# ## 1. Check Python Environment

# %%
import sys
import platform

print(f"Python version: {sys.version}")
print(f"Platform: {platform.platform()}")
print(f"Architecture: {platform.machine()}")

# List key installed packages
try:
    import pkg_resources
    key_packages = ["numpy", "matplotlib", "pandas", "IPython"]
    print("\nKey packages:")
    for pkg in key_packages:
        try:
            version = pkg_resources.get_distribution(pkg).version
            print(f"  {pkg}: {version}")
        except pkg_resources.DistributionNotFound:
            print(f"  {pkg}: NOT INSTALLED")
except ImportError:
    print("pkg_resources not available")

# %% [markdown]
# ## 2. Test Basic Arithmetic Operations

# %%
a, b = 12, 5

print(f"a = {a}, b = {b}")
print(f"Addition:       {a} + {b} = {a + b}")
print(f"Subtraction:    {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division:       {a} / {b} = {a / b:.4f}")
print(f"Floor division: {a} // {b} = {a // b}")
print(f"Modulo:         {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")
print("\nKernel is executing code correctly!")

# %% [markdown]
# ## 3. Test NumPy Array Operations

# %%
import numpy as np

arr = np.array([3, 7, 1, 9, 4, 6, 2, 8, 5, 10])

print(f"Array:              {arr}")
print(f"Mean:               {np.mean(arr):.2f}")
print(f"Sum:                {np.sum(arr)}")
print(f"Std deviation:      {np.std(arr):.4f}")
print(f"Min / Max:          {np.min(arr)} / {np.max(arr)}")
print(f"Sorted:             {np.sort(arr)}")

# 2D array test
matrix = np.arange(1, 10).reshape(3, 3)
print(f"\n3x3 Matrix:\n{matrix}")
print(f"Matrix transpose:\n{matrix.T}")
print(f"Matrix row means:   {matrix.mean(axis=1)}")

# %% [markdown]
# ## 4. Test Matplotlib Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

x = np.linspace(0, 2 * np.pi, 100)

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, np.sin(x), label="sin(x)", color="royalblue", linewidth=2)
ax.plot(x, np.cos(x), label="cos(x)", color="tomato", linewidth=2, linestyle="--")
ax.set_title("Matplotlib inline plot test", fontsize=14)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Plot rendered successfully!")

# %% [markdown]
# ## 5. Test IPython Display Features

# %%
from IPython.display import display, Markdown, HTML

# Render Markdown
display(Markdown("""
### Markdown rendering test

- **Bold text** works
- *Italic text* works
- `inline code` works
- Math: $E = mc^2$
"""))

# Render HTML
display(HTML("""
<div style="border: 2px solid #4CAF50; border-radius: 8px; padding: 12px; background: #f0fff0; color: #333; font-family: sans-serif;">
    <strong>HTML rendering test</strong><br>
    Rich output is working correctly.
    <span style="color: green; font-size: 18px;">&#10003;</span>
</div>
"""))

print("IPython display features are functional!")
